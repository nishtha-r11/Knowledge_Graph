# %%
import pandas as pd
# from transformers import pipeline
import json
from sklearn.manifold import TSNE
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AffinityPropagation
import networkx as nx
import community as community_louvain

# %%
# pip install scikit-learn
# pip install community
# pip install transformers

# %%
file_path = "props.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
# data

df = pd.DataFrame([(item["id"], item["label"], item["description"]) for item in data], columns=["PID", "Label", "Description"])
df["PID_numeric"] = df["PID"].str.extract(r'P(\d+)').astype(int)
df = df.sort_values(by="PID_numeric").drop(columns=["PID_numeric"])

df["PID"] = df["PID"].astype(str)
df_main = df.reset_index(drop=True)

# csv_file_path = "wikidata_properties_labels_sorted.csv"
# df_main.to_csv(csv_file_path, index=False, encoding="utf-8")

pd.set_option("display.max_colwidth", None)
df_main
# Out:
#           PID                                           Label  \
# 0          P6                              head of government
# 1         P10                                           video
# 2         P14                                    traffic sign
# 3         P15                                       route map
# 4         P16                               transport network
# ...       ...                                             ...
# 12439  P13326                              Toki Pona headnoun
# 12440  P13327                      Wine AppDB ID developer ID
# 12441  P13328  Brussels Inventory of Natural Heritage site ID
# 12442  P13329  Brussels Inventory of Natural Heritage tree ID
# 12443  P13330                 Korean National Species list ID
#
#                                                                                                                             Description
# 0                              head of the executive power of this town, city, municipality, state, country, or other governmental body
# 1       relevant video. For images, use the property P18. For film trailers, qualify with "object has role" (P3831)="trailer" (Q622550)
# 2      graphic symbol describing the item, used at the side of or above roads to give instructions or provide information to road users
# 3                                                                                               image of route map at Wikimedia Commons
# 4                                                                                               network the infrastructure is a part of
# ...                                                                                                                                 ...
# 12439                                                              Toki Pona common noun for which the name serves as a proper modifier
# 12440                                                                  identifier for this software or video game company at Wine AppDB
# 12441                                                                        identifier of natural sites in the Brussels-Capital Region
# 12442                                                                    identifier for remarkable trees in the Brussels-Capital Region
# 12443                                                             identifier for a taxon (species), in the Korean National Species List
#
# [12444 rows x 3 columns]

# %%
# classifier = pipeline("zero-shot-classification", model = "facebook/bart-large-mnli")
# clabels = ["movies", "TV programs", "sports programs", "news programs"]

# cthreshold = 0.5

# def category(description):
#     if "identifier" in description or "ID" in description:
#         return "negative"
#     res = classifier(description, clabels)
#     plabels = res["labels"][0]
#     cscore = res["scores"][0]
#     if cscore < cthreshold:
#         return "negative"
#     return plabels

# df["predicted_labels"] = df["Description"].apply(category)
# df

# %%
df_id = pd.read_csv("pids_relevant_file.csv")
df_id
# Out:
#         PID                                   Label  \
# 0       P10                                   video
# 1       P54                   member of sports team
# 2       P57                                director
# 3      P115                              home venue
# 4      P118                   league or competition
# ..      ...                                     ...
# 362  P13102                Damehåndbolddatabasen ID
# 363  P13146  picture of this person doing their job
# 364  P13243                      Game Jolt username
# 365  P13258           Presisov večjezični slovar ID
# 366  P13286        World Snooker Tour tournament ID
#
#                                                                                                                          Description  \
# 0    relevant video. For images, use the property P18. For film trailers, qualify with "object has role" (P3831)="trailer" (Q622550)
# 1                                                                   sports teams or clubs that the subject represents or represented
# 2                                                                   director(s) of film, TV-series, stageplay, video game or similar
# 3                                                  home stadium or venue of a sports team or applicable performing arts organization
# 4                                              league or competition in which team or player has played, or in which an event occurs
# ..                                                                                                                               ...
# 362                                                                 handball female player page on the Damehåndbolddatabasen website
# 363  picture of a person in action, especially for a sportsperson, visual artist, musican, actor. P18 is normally used for portraits
# 364                                                                                                            username on Game Jolt
# 365                                                           entry for a lexeme in the online edition of Presisov večjezični slovar
# 366                                            Identifier for a tournament on the main website of World Snooker Tour (official site)
#
#     predicted_labels
# 0             movies
# 1    sports programs
# 2        TV programs
# 3    sports programs
# 4    sports programs
# ..               ...
# 362  sports programs
# 363  sports programs
# 364  sports programs
# 365    news programs
# 366  sports programs
#
# [367 rows x 4 columns]

# %%
descriptions = df_id["Description"].to_list()
descriptions
# Out:
# ['relevant video. For images, use the property P18. For film trailers, qualify with "object has role" (P3831)="trailer" (Q622550)',
#  'sports teams or clubs that the subject represents or represented',
#  'director(s) of film, TV-series, stageplay, video game or similar',
#  'home stadium or venue of a sports team or applicable performing arts organization',
#  'league or competition in which team or player has played, or in which an event occurs',
#  'organization or person responsible for publishing books, periodicals, printed music, podcasts, games or software',
#  'actor in the subject production [use "character role" (P453) and/or "name of the character role" (P4633) as qualifiers] [use "voice actor" (P725) for voice-only role] - [use "recorded participant" (P11108) for non-fiction productions]',
#  'person(s) who produced the film, musical work, theatrical production, etc. (for film, this does not include executive producers, associate producers, etc.) [for production company, use P272, video games - use P178]',
#  'the stations next to this station, sharing the same line(s)',
#  'company that produced this film, audio or performing arts work',
#  'on-field manager or head coach of a sports club (not to be confused with a general manager P505, which is not a coaching position) or person',
#  'language in which a film or a performance work was originally created. Deprecated for written works and songs; use P407 ("language of work or name") instead.',
#  'main role in presenting a radio or television program or a performing arts show',
#  'number of an edition (first, second, ... as 1, 2, ...) or event',
#  'music release that incorporates music directly recorded from the soundtrack of an audiovisual work',
#  'language associated with this creative work (such as books, shows, songs, broadcasts or websites) or a name (for persons use "native language" (P103) and "languages spoken, written or signed" (P1412))',
#  'position or specialism of a player on a team',
#  'whether the hockey player passes or shoots left- or right-handed',
#  'network(s) or service(s) that originally broadcast a radio or television program',
#  'rank system used in several board games (e.g. go, shogi, renju), martial arts (e.g. judo, kendo, wushu) and some other games',
#  'FilmAffinity identification number of a creative work',
#  'general manager of a sports team. If they are also an on-field manager use P286 instead',
#  'person(s) that made the oath at an event, like the Olympic Games',
#  'person that lit the torch at an event, like the Olympic Games',
#  'win/lose balance for a player in doubles tournaments',
#  'win/lose balance for a player in singles tournaments',
#  'location of the terminus of a linear feature',
#  'captain of this sports team',
#  'sport that the subject participates or participated in or is associated with',
#  'which team the player was drafted by',
#  'person or institution organizing an event',
#  'characters which appear in this item (like plays, operas, operettas, books, comics, films, TV series, video games)',
#  'hand used to play a racket sport, cricket, fencing, or curling',
#  'distributor of a creative work; distributor for a record label; news agency; film distributor',
#  'the surface on which a sporting event is played',
#  'mascot of an organization, e.g. a sports team or university',
#  'parent club of this team',
#  'the narrative of the work is set in this location',
#  'actual place where this scene/film was shot. For the setting, use "narrative location" (P840)',
#  'subject headings for public libraries maintained by the Spanish Ministry of Education, Culture and Sport',
#  'three-letter abbreviation country code by the International Olympic Committee',
#  'news feed (RSS, Atom, etc.) of this person/organisation/project',
#  'person who works with the raw footage, selecting shots and combining them into sequences to create a finished motion picture',
#  'way an exoplanet was discovered',
#  'number of people (spectators, ticket holders) at an event or exhibition',
#  'number of episodes in a film/TV/radio series',
#  'total number of games officially played by a sportsman for national team',
#  'political ideology of an organization or person or of a work (such as a newspaper)',
#  'type of signal transmitted by a device',
#  'date a work was first debuted, performed or live-broadcasted',
#  'international standard code for uniquely identifying sound recordings and music video recordings',
#  'item for the list of films a person has contributed to. Don\'t use it to add film items. Instead, add actors as "cast member" (P161) on items for films, directors with "director" (P57)',
#  'object depicting this subject (object being creative works such as books, films, paintings)',
#  'number of people with non-fatal injuries in an event',
#  'winner of a competition or similar event, not to be used for awards (instead use "award received" (P166) on awardee\'s item, possibly qualified with "for work" (P1686)) or for wars or battles',
#  'matches or games a player or a team played during an event. Also a total number of matches a player officially appeared in during the whole career.',
#  'goals / points scored in a match or an event used as qualifier to the participant. Use P1358 for league points.',
#  'number of sporting matches, games or events won',
#  'number of sporting matches, games or events lost',
#  'number of matches or games drawn or tied in a league or an event',
#  'number of points in a league table or decathlon. (Use P1351 for goals/points in a match)',
#  'person who scored a point or goal in a game',
#  'time into a game when an event occurs (use with a unit)',
#  'place that a radio/TV station is licensed/required to broadcast to',
#  'executive producer of a movie, TV show, or other piece of media or entertainment',
#  'qualifier of "points/goal scored by (P1363)"',
#  'number of people missing after an event - qualify with "point in time (P585)"',
#  'country a person or a team represents when playing a sport',
#  'position of an item in its parent series (most frequently a 1-based index), generally to be used as a qualifier (different from "rank" defined as a class, and from "ranking" defined as a property for evaluating a quality)',
#  "number worn on a player's (competitor's) uniform, equipment, etc",
#  'how the player was acquired; qualifier for P54 (member of sports team)',
#  'how the player was released or transferred from the roster; qualifier for P54 (member of sports team)',
#  'referee or umpire of a match',
#  'US film classification administered by the Motion Picture Association',
#  'the object is a category for films shot at or in the subject',
#  'link to the article with the list of episodes for this series',
#  'overall pick number with which a player is selected in a sports draft',
#  'minimum numbers of players of a game',
#  'maximum numbers of players of a game',
#  "like 'Participant' (P710) but for teams. For an event like a cycle race or a football match you can use this property to list the teams and P710 to list the individuals (with 'member of sports team' (P54) as a qualifier for the individuals)",
#  'Identifier for a boxer in the BoxRec database',
#  'Identifier for an actor/actress/playwright in the Les Archives du spectacle database',
#  'permitted audience of a film, according to the German film-rating system (add Prüfnummer with qualifier "P2676")',
#  'three-character code uniquely identifying a cycling team according to UCI',
#  'image width to height ratio of films, photographs, and other images',
#  'official classification by a regulating body under which the subject (events, teams, participants, or equipment) qualifies for inclusion',
#  'rally team member who performs as a co-driver or co-pilot',
#  'number of players/sled dogs/etc. in a team at the start of a match or race',
#  'number of players/sled dogs/etc. in a team at the end of the race or match',
#  'box office takings accumulated by a film',
#  'possible macrosopic appearance of a crystal different to its molecular symmetry (crystal cell, specimens with twinning or synthetic material)',
#  'cinemetrical measure',
#  'classification of race participants',
#  'time period (historic period or era, sports season, theatre season, legislative period etc.) in which the subject occurred or with which it is associated',
#  'rating of a film in the Hungarian film rating system',
#  'production code of a television episode',
#  "an individual's best performance in a given discipline",
#  'discipline an athlete competed in within a sport',
#  'stage results and ranking of a stage race',
#  "Identifier in the database of all fencers holding an international licence at the International Fencing Federation (FIE: Fédération Internationale d'Escrime)",
#  'an image depicting the ribbon associated with a medal, order, etc.',
#  'number of seasons a television or radio series has had',
#  'ultimate point in an event or competition reached by a participant',
#  'the league above this sports league',
#  'the league below this sports league',
#  'results of a competition such as sports or elections',
#  'race for which this classification applies',
#  'person who designed the costumes for a film, television programme, etc.',
#  'competition or sports event won by the subject',
#  'type of bowling employed by a cricketer',
#  'person(s) responsible for overall aesthetic of the story of this motion picture, play, video game or similar; responsible for visual concept, producing interior, exterior, location, graphics, etc; deals with many and varied logistic related to this',
#  "URL for a men's cycling team at cqranking.com",
#  'id number for films in Russiancinema.ru',
#  'rating of a film in the former (2004–2011) Hungarian film rating system',
#  'number of the exploitation mark of a movie in France',
#  'category in the Japanese film rating system (add EIRIN number with qualifier P2676)',
#  'category assigned to a film by the Board of Film Classification (CNC) which what audiences may view it in France',
#  'Identifier for a judoka at the JudoInside.com database',
#  'assigned monetary amount for a project (for the estimated cost of a film, also commonly referred to as budget, use P2130)',
#  'officially recorded time elapsed in a sports race',
#  'name passed down by generation assumed by a master of a traditional Japanese art or sport such as kabuki or sumo',
#  'competitor or team promoted during competition',
#  'competitor or team relegated during competition',
#  'minimum age for, for example, movie certification',
#  'distinctive jersey held by a class or stage leader in a cycling competition',
#  'point of penalty in a tournament',
#  'title awarded by a chess federation to a person',
#  'person who carries the national flag of their country at an opening or closing ceremony',
#  'horizontal distance between the centers of the front and rear wheels',
#  'this event qualifies for that event',
#  'creature ridden by the subject, for instance a horse',
#  "member of the crew creating an audiovisual work, used for miscellaneous roles qualified with the job title when no specific property exists. Don't use if such a property is available: notably for cast member (P161), director (P57), etc.",
#  'distance over which a race or other event is conducted or was achieved',
#  'point system of an e.g. sports league',
#  'page of a movie on the website "Ciné-Ressources"',
#  'page of a person on the website "Ciné-Ressources"',
#  'page of an article on newadvent.org',
#  "points awarded to the winning person, team or work for a win, draw, tie or loss. If no points are awarded for some category of finish (e.g. loss) use value 0 not ''no value''.",
#  'leader of a sports tournament in one of statistical qualities (points, assists, rebounds etc.).',
#  'channel, network, website or service that broadcast this item over radio, television or the Internet',
#  'rating in the Spanish motion picture content rating system',
#  'International Tennis Hall of Fame',
#  'poster used to promote and advertise this film (if file is available on Commons). Use P154 for logos, P18 for movie stills and related images. Items about film posters can be linked with the qualifier "subject of" (P805).',
#  'rating of a movie in the Romanian content rating system',
#  'rating of a movie in the Argentinian content rating system',
#  'three-letter country code assigned by FIFA',
#  'Identifier number in "Cinema of Israel" website',
#  'property that shows the competition of which the item is a season. Use P5138 for "season of club or team".',
#  'authorization number to operate a movie theater in France',
#  'classification established according to points scored by runners',
#  'teams classification by points',
#  'classification established by team with the criterion of the race time taken from a certain number of runners in the team',
#  'predetermined number of strokes a 0-handicap golfer should require to complete a hole, a round or a tournament',
#  'fare zone that the station is in',
#  'rating of a film in the Austrian film rating system',
#  'lower rank or level in a ranked hierarchy like sport league, military ranks. If there are several possible, list each one and qualify with "criterion used" (P1013), avoid using ranks and date qualifiers. For sports leagues/taxa, use specific properties instead.',
#  'higher rank or level in a ranked hierarchy like sport league, military ranks. If there are several possible, list each one and qualify with "criterion used" (P1013), avoid using ranks and date qualifiers. For sports leagues/taxa, use specific properties instead.',
#  'number of subscribers for subscription-based companies, e.g. telecommunication companies, newspapers, pay-TV channels, software, etc.',
#  'person, who starts race at first row (leader in the starting grid)',
#  'protein (e.g. channel/pore protein) for which this chemical compound acts as a blocker',
#  'basketball player Id in Safsal website',
#  'basketball coach Id in Safsal website',
#  'film format used to create a work (aliases: film gauge, film size)',
#  'script version for subject film is described at',
#  'rating of a film in the South Korean film/video rating system',
#  'the rules for classification of a sports league',
#  'rating of a film in the Mexican film classification system',
#  'the slope rating of a golf course is a measure of its difficulty for bogey golfers',
#  'number of perpetrators in an event, as reported by reliable sources',
#  'final event of a competition',
#  'channel number of given TV channel; use with the mandatory qualifier P137',
#  'the level of the sport league in the sport league system',
#  "address on the Mastodon decentralized social network (the form is 'user@server.domain' without a leading '@')",
#  'rating given by EGF (European Go Federation) to European go players',
#  'highest age a person is eligible to do something, for example be member in youth organisation or sport teams, some positions like judges, clinical trials, etc',
#  'constructs of rules or methods designed for interaction with the game state',
#  'username on the social news website Reddit',
#  'average number of readers of a newspaper or other periodical, per issue',
#  'measured parameter for stars',
#  'filmmaking method that the cameras were placed by. Use single-camera (Q2918907) or multiple-camera (Q738160)',
#  'person ranked for this cycling stage or race',
#  'person ranked as "best combative" for this cycling stage or race',
#  'person ranked as "best sprinter" for this cycling stage or race',
#  'person ranked as young participant for this cycling stage or race',
#  'person ranked in "best at combination" for this cycling stage or race',
#  'time between two passes of an object in front of a distant star seen from another orbiting object',
#  'rating of a film or video game in the South African media content rating system',
#  'work in which a fictional/mythical character or entity first appeared',
#  'person who designed the stage or film set of this item',
#  'trophy awarded at the end of a selection process or of a competition, usually to winners or finishers under the form of a cup, a medal, a diploma',
#  'this work contains articles presented at the given event',
#  'month or season when sports competition begins',
#  'for figure skating scores breakdown',
#  'for figure skating scores breakdown',
#  'for figure skating scores breakdown',
#  'property for swimmeets from swimrankings.net',
#  "Identifier for a female rugby union player selected with Ireland women's national team on the Irish Rugby Football Union website",
#  'season of a series (televison, web, podcast)',
#  'number of registered players in a sport or people practicing a sport in a region',
#  'in snooker, the number of career century breaks at officіal professional tournaments',
#  'secondary classification for bicycle race statistics used in hispanic language countries',
#  'prior event or achievement that a person or team needs to complete before joining or obtaining the item topic, e.g. a qualifying round of a sports event, a lower-level course in an educational program, or a lower level of a professional qualification',
#  'new work of art (film, book, software, etc.) derived from major part of this work',
#  'number of clubs active in a given sport for a region',
#  'METeorological Aerodrome Report',
#  'person responsible for the sound on a stage, in a film or in a radio drama',
#  'person invited in a talk show',
#  "PLEASE USE P1238 FOR THE CURRENT PLAYER PAGE. Identifier for a football (soccer) player's page at Fogis.se, a Swedish Football Association database.",
#  'person who does the fastest lap during a motorsport race',
#  'assistant stage director of a performing arts, film or television production',
#  'club or team that played the season',
#  'rating of a film or theatrical production in the Portuguese classification system',
#  'rating in the Finnish film and television rating system',
#  'rating in the Singaporean film and video game rating system',
#  'edition of sports competitions at which the club or team that played a season competed at. Use this to link items for team seasons to items for specific seasons of competitions.Sample: 2012–13 FC Barcelona season → 2012–13 UEFA Champions League',
#  'Wikidata property for authority control for sports people',
#  'sportsarenas/stadium database',
#  'person riding the horse in the race',
#  'number of laps completed by a race participant',
#  'NewsCode for an item, as defined by the International Press Telecommunications Council (IPTC)',
#  'the artist id on pixiv',
#  'number of viewers of a television or broadcasting program; web traffic on websites',
#  'number assigned to a section of sportspeople in a sporting competition; e.g. "3" for a "quarter-final 3"; use together with property "stage reached" (P2443)',
#  'page on the Centre national de la recherche scientifique website presenting a person who has received certain prizes or medals',
#  'an audiobook, film, music album, comic, ebook, or television series on Hoopla',
#  'Croatian art/theater linked open data',
#  'seeding information of a participant of a sports event',
#  'person responsible for the creation and integration of film and motion graphics on a stage',
#  "Women's Japan Basketball League",
#  'Japan Professional Basketball League',
#  'rating of a film in the Danish movie content rating system',
#  'official supplier of sports goods to a given sports club, sportsperson or a national sports team',
#  'link to category entity contains films in this language',
#  'background information on historical and current events, biographies of famous people',
#  'sports club or team for which this person is or was on-field manager or coach',
#  'Wikimedia category for players playing for a sports team',
#  'to indicate what month of the year a sports season ends',
#  'Hembygdsportalen is a site containing local history material added by +600 local history communities in Sweden',
#  'official profile of a female association football (soccer) player from Liga MX Femenil, the top level Mexican league for women',
#  'background information on organizations, political parties, biographies of famous people',
#  'background information on historical and current events, locations, biographies of famous people',
#  'lexeme described or discussed in this item',
#  'artist in charge of adding colors to drawings, comics, movie film, etc.',
#  'Record on skiresort.info for any specific ski resort',
#  'Record page on www.Skimap.org for ski resort, with current and historical official published maps of lifts and ski-runs',
#  'rating in the Indian film rating system',
#  'number of a tag of Bilibili, a Chinese video website similar to YouTube or Niconico',
#  'goalscoring statistic',
#  'house number used for recreational and provisional buildings in Czechia, formerly also in Slovakia (eg. cottages)',
#  'system of tires, tire air, springs, shock absorbers and linkages that connects a vehicle to its front wheels and allows relative motion between the two',
#  'system of tires, tire air, springs, shock absorbers and linkages that connects a vehicle to its rear wheels and allows relative motion between the two',
#  'sports statistic',
#  'sports statistic',
#  'goalscoring statistic',
#  'sports statistic',
#  'sports statistic',
#  'league system the league belongs to',
#  'highest break made by a snooker player in their career or in a tournament',
#  'media file showing the order of strokes in a CJKV character',
#  'Canadian movie classification',
#  'movie classification for the Régie du Cinéma Québécois',
#  'Mini biographies of the inductees to the Motorsports Hall of Fame of America',
#  'rank in the Deloitte Football Money League',
#  'short film integrating this composition with imagery',
#  'property for various sportclubs on sportsport.ba website',
#  'the length of time a image sensor or photographic film is exposed to light.',
#  'sports team for which a person or a group is a supporter',
#  'light sensitivity of film or digital sensor (e.g. ISO/ASA 100)',
#  'property for various sportpersons bios and stats on sportsport.ba website',
#  'wiki name for this topic on Gamepedia',
#  'muscle that is targeted in a physical exercise',
#  'the part of a sporting match when an event takes place',
#  'video system hardware that the item uses',
#  'external Identifiers for players participating in Indian Super League',
#  'competition quality ranking assigned by World Athletics (formerly IAAF) used for comparison and future Olympic qualification',
#  'inline speed skater-database',
#  'online repository of newspaper',
#  'content descriptors for this video game, film, television show, etc.',
#  'Database about Films adaptations of literary work (18th and 19th century)',
#  'database of film adaptations of literary work (18th and 19th century)',
#  'Database about Films adaptations of literary work (18th and 19th century)',
#  'Database about Films adaptations of literary work (18th and 19th century)',
#  'rating certificate of a film in the Irish content classification system',
#  "link to a film's entry at the MPPDA Digital Archive",
#  'official number given by the NHA to official clubs',
#  'format of a sports tournament',
#  'this creative work belongs to this media franchise',
#  'image of the subject taken from the air',
#  'a reference point on a ski jumping hill',
#  'ski jumping hill size',
#  "reference number for a film or video game (-2012) media content rating decision on BBFC's official website",
#  'Hong Kong film classification system',
#  'identifiant for a player in HLTV',
#  'shots or other attempts to score points in a sporting event',
#  'rating of a film or television program in the Philippines',
#  'name of the official Parabola package',
#  'rating in the Taiwanese movie content rating system',
#  'time (usually minutes) played by a participant in a sporting event',
#  'number of batting attempts in a baseball career or game(s)',
#  'number of hits earned in a baseball career or game(s)',
#  'number of walks in a baseball career or game(s)',
#  'number of RBIs attributed to a baseball player in a career or game(s)',
#  'number of bases stolen by a baseball player in a career or game(s)',
#  'number of doubles hit by a baseball player in a career or game(s)',
#  'number of triples hit by a baseball player in a career or game(s)',
#  'Identifier for bobsleigh and skeleton competitions in the IBSF database',
#  'unique identification number of an individual horse or other equine animal used in Europe',
#  'earned run average of a baseball pitcher in a career or season',
#  'official podcast of this person or organization',
#  'particular personality trait which applies to this fictional character',
#  'filmmaker in the catalogue of IFFR',
#  'Category of the sports facility according to the UEFA Stadium Infrastructure Regulations',
#  'age rating category as designated by the South Korean Game Rating and Administration Committee (GRAC)',
#  'a work, event, etc. for which the subject work was created (e.g., a presidential inauguration that a poem was written for; a competition that a play was created for; a film that a screenplay was written for)',
#  'a work, event, etc. for which a musical composition was created (e.g., a play for which incidental music was composed; a ballet for which ballet music was written; a film for which motion picture music was created)',
#  'number of tries marked during a rugby competition',
#  'identify for a creative work in Vokrug.tv',
#  'identify for person in Vokrug.tv',
#  'identificator for film or TV-program in Smotrim.ru',
#  'Identifier for an item on Norgeshistorie.no',
#  'the person who is legally responsible for a publication (text, images, audio, or video, including broadcast). Definitions and translations may vary depending on the country and legislation.',
#  'personal trainer of the athlete',
#  'identifying sound recordings and music video recordings via their barcodes',
#  'page on the German Kinowiki, a website about old and new cinema buildings in Germany and elsewhere in Europe',
#  'role in a theatrical, motion picture, television, or other work that a performer is particularly known for',
#  "the name of a school's athletics program, as opposed to individual teams in particular sports",
#  'number of races started in pole position',
#  'number of podium finishes a participant achieved',
#  'sports awards',
#  'soundtrack of this audiovisual work',
#  'exemplary image taken from a set, determined to represent the subject in a given role',
#  'finishing move used by an athlete in professional wrestling',
#  'number of fastest laps a driver is credited with over a series, season, or career',
#  "idientifier for an footballer's page on the website of the Russian Football Union",
#  'power series expansion of the subject',
#  'rating in the film classification system of Kenya',
#  "footballer's page at the Asian Football Confederation",
#  "a person's page on British Athletics",
#  'website or email address which allows a user to unsubscribe to an email subscription for news, announcements, offers and updates relating to an organisation, product or service',
#  'Identifier for a Canadian Broadcasting Corporation GEM (a media URL for a television series, television episodes, documentaries, or other media)',
#  'the number assigned to professional shogi players by the Japan Shogi Association',
#  'movie page in Mosfilm online cinema',
#  'page of the actor, director, screenwriter in the Mosfilm online cinema',
#  'page of the program, series or film on the NTV website',
#  'page of a golfer on the Epson Tour website',
#  'page of film personalities in the Encyclopedia of National Cinema',
#  'Identifier for an athlete profile on nbcolympics.com',
#  'IMDb keyword related to movies and television programs',
#  'significance or status of a sports competition for a league, tour, association, etc.',
#  'number issued by the Federal Communications agency to uniquely identify a broadcast antenna structure',
#  'the maximum sustainable force with which this vehicle can pull or push another object. Alternatively for road- or track-vehicles, the maximum weight of an object on wheels that this vehicle can reliably and safely pull given usual slopes',
#  'DVD/Blu-ray spine number of a film or film series in The Criterion Collection',
#  'manager that is responsible for the administration of a feature film or television production',
#  'athlete page on Rowing Canada',
#  "best scorer of a single season of a team sport's competition or the best ever scorer of the history of a competition",
#  'person who participates in a television show as a competition judge or mentor',
#  'Identifier in Traineras website which lists competetive clubs and their results',
#  "address for a channel on a PeerTube instance, in 'user@server.domain' format",
#  'person who is responsible for the day-to-day operation of a television show',
#  'Identifier for basketball players in thisisbasketball.be',
#  'entry for a Persian lexeme in the farhang.ru online reproduction of Yuri Rubinchik’s Persian–Russian dictionary',
#  'person(s) who devised and developed this game',
#  'handball female player page on the Damehåndbolddatabasen website',
#  'picture of a person in action, especially for a sportsperson, visual artist, musican, actor. P18 is normally used for portraits',
#  'username on Game Jolt',
#  'entry for a lexeme in the online edition of Presisov večjezični slovar',
#  'Identifier for a tournament on the main website of World Snooker Tour (official site)']

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
embedding = model.encode(descriptions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = SentenceTransformer("all-MiniLM-L6-v2")
#       2 embedding = model.encode(descriptions)
#
# NameError: name 'SentenceTransformer' is not defined

# %%
sim_matrix = cosine_similarity(embedding)
# af = AffinityPropagation(affinity='precomputed')
# direct_cluster = af.fit_predict(sim_matrix)
# df["D_cluster"] = direct_cluster
# df.head(5)

G = nx.Graph()
for i, entity in enumerate(df["Named Entity"]):
    G.add_node(i, name=entity)
for i in range(len(sim_matrix)):
    for j in range(i+1, len(sim_matrix)):
        if sim_matrix[i,j] > 0.5:
            G.add_edge(i,j,weight=sim_matrix[i,j])
partition = community_louvain.best_partition(G)
df["Graph_cluster"] = df.index.map(partition)

# %%
tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)
df["x"] = embeddings_2d[:,0]
df["y"] = embeddings_2d[:,1]
plt.figure(figsize=(12,5))

# plt.subplot(1,2,1)
# sns.scatterplot(x="X", y="Y", hue = "D_cluster", data=df, palette="tab10", s=100, legend = False)
# plt.title("Direct cluster")
# plt.xlabel("tsne dim1")
# plt.ylabel("tsne dim2")
# for i, row in df.iterrows():
#     plt.text(row["x"], row["y"], row["Named Entity"], fontsize = 9, ha="right")

# plt.subplot(1,2,2)
sns.scatterplot(x="X", y="Y", hue = "Graph_cluster", data=df, palette="tab10", s=100, legend = False)
plt.title("Graph based cluster")
plt.xlabel("tsne dim1")
plt.ylabel("tsne dim2")
for i, row in df.iterrows():
    plt.text(row["x"], row["y"], row["Named Entity"], fontsize = 9, ha="right")

plt.tight_layout()
plt.show()
